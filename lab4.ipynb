# %%
# 1. initialize the client
from elasticsearch import Elasticsearch

HOST = "https://localhost:9200"
ELASTIC_USER = "elastic"
# The password for the 'elastic' user generated by Elasticsearch
ELASTIC_PASSWORD = "BD=khuw3Z2Sk40Ue-VwL"
# The path of ca certificates 
CA_CERTS = "/etc/elasticsearch/certs/http_ca.crt"

# Create the client instance
es = Elasticsearch(
    hosts = HOST,
    ca_certs = CA_CERTS,
    http_auth = (ELASTIC_USER, ELASTIC_PASSWORD),
)
es.info()
# Out:
# {'name': 'wakuwa-Inspiron-3501',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'PuE_kGO9TVqhIMExiqp7Zg',
#  'version': {'number': '8.6.2',
#   'build_flavor': 'default',
#   'build_type': 'deb',
#   'build_hash': '2d58d0f136141f03239816a4e360a8d17b6d8f29',
#   'build_date': '2023-02-13T09:35:20.314882762Z',
#   'build_snapshot': False,
#   'lucene_version': '9.4.2',
#   'minimum_wire_compatibility_version': '7.17.0',
#   'minimum_index_compatibility_version': '7.0.0'},
#  'tagline': 'You Know, for Search'}
